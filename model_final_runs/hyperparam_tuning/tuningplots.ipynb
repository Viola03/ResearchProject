# %%
# Baselinemodel

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["axes.unicode_minus"] = False  # Use hyphen (-) instead of the missing Unicode minus sign

# %%
base = pd.read_csv('/users/zw21147/ResearchProject/model_final_runs/hyperparam_tuning/losses_data.csv')
bs512 = pd.read_csv('/users/zw21147/ResearchProject/model_final_runs/hyperparam_tuning/batchsize512.csv')
bs5 = pd.read_csv('/users/zw21147/ResearchProject/model_final_runs/hyperparam_tuning/bs5.csv')

# %%
fig = plt.subplot()
plt.plot(bs5['iteration'], bs5['total_loss'], alpha=0.2, label='batch_size = 5')
plt.plot(base['iteration'], base['total_loss'], alpha=0.5, label='batch_size = 256')
plt.plot(bs512['iteration'][:15000], bs512['total_loss'][:15000], alpha=0.5, label='batch_size = 512')
plt.xlabel('Iterations')
plt.ylabel('Total Loss')
plt.legend()
