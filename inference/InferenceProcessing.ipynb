# %% [markdown]
# ### Plots for Inference Run on Unseen Validation Set

# %%
import numpy as np
import pandas as pd
import uproot

## Original Data
file = uproot.open('/users/zw21147/ResearchProject/datasets/split/validation_renamed.root')
tree = file["DecayTree"] 
df = tree.arrays(library="pd")

# %%
## Reconstructed data
df_reco = pd.read_csv('/users/zw21147/ResearchProject/inference/validation_inference.csv')

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["axes.unicode_minus"] = False  

# Set up the grid layout
num_cols = len(df.columns)
cols = 2  # Number of columns in the grid
rows = (num_cols // cols) + (num_cols % cols > 0)

fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 4))
#fig.suptitle('Inference Run on Validatory Subset')
axes = axes.flatten() 

for i, col in enumerate(df_reco.columns):
    data = df_reco[col].dropna() 

    if len(data) > 0:
        #lower_bound, upper_bound = np.percentile(data, [1.5, 99.9])  # Exclude outliers
        axes[i].hist(data, bins=100, alpha=0.75, histtype = 'step')
        axes[i].hist(df[col], bins=100, alpha=0.75, histtype = 'step')
        axes[i].set_title(col)
        axes[i].set_xlabel("Value")
        axes[i].set_ylabel("Frequency")

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
df_reco.columns
# Out:
# Index(['B_plus_ENDVERTEX_CHI2', 'B_plus_IPCHI2_OWNPV', 'B_plus_FDCHI2_OWNPV',
#        'B_plus_DIRA_OWNPV', 'K_plus_IPCHI2_OWNPV', 'K_plus_TRACK_CHI2NDOF',
#        'e_minus_IPCHI2_OWNPV', 'e_minus_TRACK_CHI2NDOF', 'e_plus_IPCHI2_OWNPV',
#        'e_plus_TRACK_CHI2NDOF'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt 

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["axes.unicode_minus"] = False  

fig, axes = plt.subplots(5, 2, figsize=(10, 20))  

# === PLOT 1 ===
axes[0, 0].hist(df_reco["B_plus_ENDVERTEX_CHI2"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0.5,99.5), density=True)
axes[0, 0].hist(df["B_plus_ENDVERTEX_CHI2"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0.5,99.5), density=True)
axes[0, 0].set_title("B_plus_ENDVERTEX_CHI2")
axes[0, 0].set_xlabel("Value")
axes[0, 0].set_ylabel("Frequency")
axes[0, 0].legend()

# === PLOT 2 ===
axes[0, 1].hist(df_reco["B_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0.5,99.5), density=True)
axes[0, 1].hist(df["B_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0.5,99.5), density=True)
axes[0, 1].set_title("B_plus_IPCHI2_OWNPV")
axes[0, 1].set_xlabel("Value")
axes[0, 1].set_ylabel("Frequency")
axes[0, 1].legend()

# === PLOT 3 ===
axes[1, 0].hist(df_reco["B_plus_FDCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0,99.99), density=True)
axes[1, 0].hist(df["B_plus_FDCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0,99.99), density=True)
axes[1, 0].set_title("B_plus_FDCHI2_OWNPV")
axes[1, 0].set_xlabel("Value")
axes[1, 0].set_ylabel("Frequency")
axes[1, 0].legend()

# === PLOT 4 ===
axes[1, 1].hist(df_reco["B_plus_DIRA_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", density=True)
axes[1, 1].hist(df["B_plus_DIRA_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", density=True)
axes[1, 1].set_title("B_plus_DIRA_OWNPV")
axes[1, 1].set_xlabel("Value")
axes[1, 1].set_ylabel("Frequency")
axes[1, 1].legend()

# === PLOT 5 ===
axes[2, 0].hist(df_reco["K_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0.5,99), density=True)
axes[2, 0].hist(df["K_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0.5,99), density=True)
axes[2, 0].set_title("K_plus_IPCHI2_OWNPV")
axes[2, 0].set_xlabel("Value")
axes[2, 0].set_ylabel("Frequency")
axes[2, 0].legend()

# === PLOT 6 ===
axes[2, 1].hist(df_reco["K_plus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", density=True)
axes[2, 1].hist(df["K_plus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", density=True)
axes[2, 1].set_title("K_plus_TRACK_CHI2NDOF")
axes[2, 1].set_xlabel("Value")
axes[2, 1].set_ylabel("Frequency")
axes[2, 1].legend()

# === PLOT 7 ===
axes[3, 0].hist(df_reco["e_minus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0.5,99.5), density=True)
axes[3, 0].hist(df["e_minus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0.5,99.5), density=True)
axes[3, 0].set_title("e_minus_IPCHI2_OWNPV")
axes[3, 0].set_xlabel("Value")
axes[3, 0].set_ylabel("Frequency")
axes[3, 0].legend()

# === PLOT 8 ===
axes[3, 1].hist(df_reco["e_minus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", density=True)
axes[3, 1].hist(df["e_minus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", density=True)
axes[3, 1].set_title("e_minus_TRACK_CHI2NDOF")
axes[3, 1].set_xlabel("Value")
axes[3, 1].set_ylabel("Frequency")
axes[3, 1].legend()

# === PLOT 9 ===
axes[4, 0].hist(df_reco["e_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0.5,99.5), density=True)
axes[4, 0].hist(df["e_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0.5,99.5), density=True)
axes[4, 0].set_title("e_plus_IPCHI2_OWNPV")
axes[4, 0].set_xlabel("Value")
axes[4, 0].set_ylabel("Frequency")
axes[4, 0].legend()

# === PLOT 10 ===
axes[4, 1].hist(df_reco["e_plus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", density=True)
axes[4, 1].hist(df["e_plus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", density=True)
axes[4, 1].set_title("e_plus_TRACK_CHI2NDOF")
axes[4, 1].set_xlabel("Value")
axes[4, 1].set_ylabel("Frequency")
axes[4, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## RapidSim Conditions

# %%
## Reconstructed data
rs_reco = pd.read_csv('/users/zw21147/ResearchProject/inference/rapidsim_inference.csv')

# %%
import matplotlib.pyplot as plt 

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["axes.unicode_minus"] = False  

fig, axes = plt.subplots(5, 2, figsize=(10, 20))  

# === PLOT 1 ===
axes[0, 0].hist(rs_reco["B_plus_ENDVERTEX_CHI2"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0.5,99.5), density=True)
# axes[0, 0].hist(df["B_plus_ENDVERTEX_CHI2"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0.5,99.5), density=True)
axes[0, 0].set_title("B_plus_ENDVERTEX_CHI2")
axes[0, 0].set_xlabel("Value")
axes[0, 0].set_ylabel("Frequency")
axes[0, 0].legend()

# === PLOT 2 ===
axes[0, 1].hist(rs_reco["B_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0.5,99.5), density=True)
# axes[0, 1].hist(df["B_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0.5,99.5), density=True)
axes[0, 1].set_title("B_plus_IPCHI2_OWNPV")
axes[0, 1].set_xlabel("Value")
axes[0, 1].set_ylabel("Frequency")
axes[0, 1].legend()

# === PLOT 3 ===
axes[1, 0].hist(rs_reco["B_plus_FDCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0,99.99), density=True)
# axes[1, 0].hist(df["B_plus_FDCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0,99.99), density=True)
axes[1, 0].set_title("B_plus_FDCHI2_OWNPV")
axes[1, 0].set_xlabel("Value")
axes[1, 0].set_ylabel("Frequency")
axes[1, 0].legend()

# === PLOT 4 ===
axes[1, 1].hist(rs_reco["B_plus_DIRA_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", density=True)
# axes[1, 1].hist(df["B_plus_DIRA_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", density=True)
axes[1, 1].set_title("B_plus_DIRA_OWNPV")
axes[1, 1].set_xlabel("Value")
axes[1, 1].set_ylabel("Frequency")
axes[1, 1].legend()

# === PLOT 5 ===
axes[2, 0].hist(rs_reco["K_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0.5,99), density=True)
# axes[2, 0].hist(df["K_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0.5,99), density=True)
axes[2, 0].set_title("K_plus_IPCHI2_OWNPV")
axes[2, 0].set_xlabel("Value")
axes[2, 0].set_ylabel("Frequency")
axes[2, 0].legend()

# === PLOT 6 ===
axes[2, 1].hist(rs_reco["K_plus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", density=True)
# axes[2, 1].hist(df["K_plus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", density=True)
axes[2, 1].set_title("K_plus_TRACK_CHI2NDOF")
axes[2, 1].set_xlabel("Value")
axes[2, 1].set_ylabel("Frequency")
axes[2, 1].legend()

# === PLOT 7 ===
axes[3, 0].hist(rs_reco["e_minus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0.5,99.5), density=True)
# axes[3, 0].hist(df["e_minus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0.5,99.5), density=True)
axes[3, 0].set_title("e_minus_IPCHI2_OWNPV")
axes[3, 0].set_xlabel("Value")
axes[3, 0].set_ylabel("Frequency")
axes[3, 0].legend()

# === PLOT 8 ===
axes[3, 1].hist(rs_reco["e_minus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", density=True)
# axes[3, 1].hist(df["e_minus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", density=True)
axes[3, 1].set_title("e_minus_TRACK_CHI2NDOF")
axes[3, 1].set_xlabel("Value")
axes[3, 1].set_ylabel("Frequency")
axes[3, 1].legend()

# === PLOT 9 ===
axes[4, 0].hist(rs_reco["e_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", range=(0.5,99.5), density=True)
# axes[4, 0].hist(df["e_plus_IPCHI2_OWNPV"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", range=(0.5,99.5), density=True)
axes[4, 0].set_title("e_plus_IPCHI2_OWNPV")
axes[4, 0].set_xlabel("Value")
axes[4, 0].set_ylabel("Frequency")
axes[4, 0].legend()

# === PLOT 10 ===
axes[4, 1].hist(rs_reco["e_plus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="Reconstructed", density=True)
# axes[4, 1].hist(df["e_plus_TRACK_CHI2NDOF"].dropna(), bins=100, alpha=0.75, histtype='step', label="True", density=True)
axes[4, 1].set_title("e_plus_TRACK_CHI2NDOF")
axes[4, 1].set_xlabel("Value")
axes[4, 1].set_ylabel("Frequency")
axes[4, 1].legend()

plt.tight_layout()
plt.show()

# %%
data = rs_reco
#data = df_reco

# %% [markdown]
# Validate as combinatorial

# %%
import sys
import os

# directory where validationtools is located
sys.path.append("/users/zw21147/ResearchProject/scripts/validation")

from validationtools import query_BDT

# %%
# Define the parameters
mother = "B_plus"
particles = ["K_plus", "e_plus", "e_minus"]
intermediate = "J_psi_1S"
BDT_branch_name = "BDT_output"
tag = ''

BDT_targets = [
    f"{tag}{mother}_ENDVERTEX_CHI2",
    f"{tag}{mother}_IPCHI2_OWNPV",
    f"{tag}{mother}_FDCHI2_OWNPV",
    f"{tag}{mother}_DIRA_OWNPV",
    f"{tag}{particles[0]}_IPCHI2_OWNPV",
    f"{tag}{particles[0]}_TRACK_CHI2NDOF",
    f"{tag}{particles[1]}_IPCHI2_OWNPV",
    f"{tag}{particles[1]}_TRACK_CHI2NDOF",
    f"{tag}{particles[2]}_IPCHI2_OWNPV",
    f"{tag}{particles[2]}_TRACK_CHI2NDOF",
    f"{tag}{intermediate}_FDCHI2_OWNPV",
    f"{tag}{intermediate}_IPCHI2_OWNPV",
]

for target in BDT_targets:
    if target not in data.columns:
        data[target] = df[target]  # Fill missing columns with 0

# Apply the function
data = query_BDT(data, mother, particles, intermediate, BDT_branch_name)

plt.hist(data['BDT_output'], bins=100,  color="royalblue")

plt.xlabel("Value")
plt.ylabel("Frequency")

plt.title("SignalBDT Output on RapidSim Inference")

plt.grid(axis="y", linestyle="--")

plt.show()
